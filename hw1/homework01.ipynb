# %% [markdown]
# # Homework 01

# %% [markdown]
# In this exercise, you will warm up / refresh your Python skills by analyzing some real data inside of a Jupyter notebook environment. You should write whatever **Python** code you like to solve these problems. You can search on the web for documentation and techniques to help you solve the problem. See especially the official [Python tutorial](https://docs.python.org/3/tutorial/) and [documentation](https://docs.python.org/3/).
#
# For grading, we will be using an autograder in [Gradescope](http://gradescope.com/). It grades based on values in specific variables or function names. Read the following instructions carefully. It is repeated for you again at the end of this notebook.
#
# You should make sure any code that you write to answer the questions is included in this notebook. You are **required** to go to the Kernel option and choose **"Restart & Run All"** before submission. Double check that your entire notebook runs correctly and generates the expected output. Finally, make sure to save your work (timestamp at the top tells you the last checkpoint and whether there are unsaved changes). When you finish, submit your assignment at Gradescope. **Submissions not prepared correctly as above will lose points.**
#
# Make sure to also read the problem carefully to know what names to use so the autograder can correctly find your answers.
#
# There are 3 parts in this exercise, with first 2 required. The last part is optional (worth 0.0 points) but our autograder also gives feedback on it. You are therefore welcome to submit your answers to the optional part along with the required parts.

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 19.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 27.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 28.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
boston_df = pd.read_csv('boston.csv')
boston_df
# Out:
#         sourceid  dstid  hod  ride time
# 0            584     33    7  11.866000
# 1           1013   1116   13  17.799333
# 2            884   1190   22  19.348833
# 3            211    364    1   1.723500
# 4            218   1189    7  42.558833
# ...          ...    ...  ...        ...
# 199995       448    333    1  14.460833
# 199996       207    810   10  18.052333
# 199997       364    773    8   8.431333
# 199998        33    487    3   8.291667
# 199999      1040    435    3   4.037667
#
# [200000 rows x 4 columns]

# %%
print(f"length: {len(text)} characters, {len(text.split())} words")
print(f"\nfirst 500 characters:\n{text[:500]}...")
# Out:
# Length: 5760 characters, 1002 words
#
# First 500 characters:
# it was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of light, it was the season of darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to heaven, we were all going direct the other way- in short, the period was so far like the present period, that some of its noisiest...

# %% [markdown]
# ## Part 1: Central Tendency
#
# This part is about [measures of central tendency](https://www.youtube.com/watch?v=MF6ij7tckI0&ab_channel=StudyHall). Watch the video in the link if you are unfamiliar with mean, median, and mode.

# %% [markdown]
# The goal of this section is to help you start building an intuition of the differences between the mean, median, and mode. It does this through brain teaser-like number manipulation problems.

# %% [markdown]
# ### Question 1 (4 points)
# Complete the function `central_measures` below that takes as input a list `lst` of (not necessarily distinct) numbers and an integer $k \geq 0$. It should output the mean, median, and mode of `lst` after the largest $k$ numbers in `lst` are removed. You may assume `lst` always contains at least $(k+1)$ numbers, so the resulting list is not empty. If there exist multiple modes, you may return any of them, or all of them as a list.
#
# You may find the built-in Python [`sorted`](https://docs.python.org/3/howto/sorting.html) function and the [`statistics`](https://docs.python.org/3/library/statistics.html#) module (imported as `stat` below for you) useful. You can also import and use other packages like `numpy` or `scipy` if you are comfortable with using them. Do not change the default variable names.

# %%
import statistics as stat

# Code for question 1
def central_measures(lst, k): # DO NOT MODIFY THIS LINE
    mean = ...
    median = ...
    mode = ...
    return mean, median, mode # DO NOT MODIFY THIS LINE

# Your code should output (3, 2, 2) or (3, 2, [2]) for the example below
central_measures([1,2,2,4,6,6], 1)

# %% [markdown]
# ### Question 2 (12 points, 4 each)
# - Put in `q2_1` a list of 5 positive numbers such that its **mean** remains the same when one of its maximum values is removed (so it is only 4 long).
#
# - Put in `q2_2` a list of 5 positive numbers (of at least 3 distinct values) such that its **median** remains the same when one of its maximum values is removed.
#
# - Put in `q2_3` a list of 5 positive numbers such that its *unique* **mode** *changes* when its **two** largest values are removed. (Note: This means there should only be *one* mode both before and after the removal.)
#
# You are welcome to use your `central_measures` function to help you figure out the answer to these questions.

# %%
# Code for question 2
q2_1 = ...
q2_2 = ...
q2_3 = ...

# %% [markdown]
# ### Question 3 (4 points)
# Put in `q3` a list of 5 positive numbers such that:
# - its mean is larger than 50;
# - the absolute difference between its mean and median is at most 5;
# - after removing one of its maximum value(s), the median does not change;
# - after removing one of its maximum value(s), the absolute difference between the old mean and the new mean is larger than 25.
#
# You are welcome to use your `central_measures` function to help you figure out the answer.

# %% [markdown]
# Hint: We recommend you start with a list containing the number 1, three numbers below 100, and then change the value of the maximum number(s) to see what happens.

# %%
# Code for question 3
q3 = ...

# %% [markdown]
# ## Part 2: Rides
#
# The [boston.csv](boston.csv) file contains data on weekday Uber rides in the Boston, Massachusetts metropolitan areas from the [Uber Movement](https://movement.uber.com) project. The `sourceid` and `dstid` columns contain codes corresponding to start and end locations of each ride. The `hod` column contains codes corresponding to the hour of the day the ride took place. The `ride time` column contains the length of the ride, in minutes.
#
# The code below will open the file and read the data as a list of rows, with each row represented as a string. It then prints the first four rows. Note that the first (index 0) row contains the column headers.

# %%
# Do NOT change this code or the autograder may not work
f = open('boston.csv')
data = f.readlines()
f.close()
for row in data[:4]:
    print(row)

# %% [markdown]
# ### Question 4 (4 points)
# In the variable `q4` place how many rides are listed in the file.

# %%
# Code for question 4
q4 = ...

# %% [markdown]
# ### Question 5 (4 points)
# In the variable `q5` place the length of the longest ride.

# %%
# Code for question 5
q5 = ...

# %% [markdown]
# ### Question 6 (4 points)
# In the variable `q6` place the percent of rides that are under 10 minutes. The percent should be between 0 and 1.

# %%
# Code for question 6
q6 = ...

# %% [markdown]
# ### Question 7 (4 points)
# For each HOD (hour of day), count how many rides take place during that hour. Put it in a list where index 0 has the number of rides where `hod` was 0, at index 1 where `hod` was 1, etc. until index 23. This means your list will be 24 long. Put this list in a variable called `q7`. Every element in `q7` should be an `int` type.

# %%
# Code for question 7
q7 = ...

# %% [markdown]
# ### Question 8 (4 points)
# What are the three most common **start** locations (`sourceid`) for rides in the dataset?
#
# Place your answer in the variable `q8` sorted with the most common location first. **Every item in `q8` should be of a `str` type.** Although the `sourceid` look like numbers, they do not convey numerical meanings (e.g., taking the mean of them does not make sense), so they should be treated as strings.
#
# *Hint. You can also use `sorted` for this question. However, using `sorted` on a huge list will make your code very slow. Instead, think about using `sorted` on a smaller object (e.g., a dictionary).*

# %%
# Code for question 8
q8 = ...

# %% [markdown]
# ## Part 3: Text (Optional, 0 points, with autograder feedback)
# The `text.txt` file contains the opening sentences of Charles' Dickens novel *A Tale of Two Cities*. Run the code below. It will read the file, store it in a string variable `text`, and print the first 500 characters.

# %%
# Do NOT change this code or the autograder may not work
f = open('text.txt')
text = f.read()
f.close()

print(text[:500], '...')

# %% [markdown]
# ### Question 9
# In the variable `q9_1` put the first sentence of the text. In the variable `q9_2` put the last sentence of the text. You may assume sentences only end with a period (`'.'`).
#
# You may find the Python `split` method for strings to be useful: https://docs.python.org/3/library/stdtypes.html?highlight=split#str.split `sep='.'`.

# %%
# Code for question 9
q9_1 = ...
q9_2 = ...

# %% [markdown]
# ### Question 10
# In the variable `q10` place the total number of vowels (`a`, `e`, `i`, `o`, `u`) that appear in the text.

# %%
# Code for question 10
q10 = ...

# %% [markdown]
# ### Question 11
# A trigram is a string of exactly 3 characters (or a string with length exactly 3), including blank spaces. For example, the first five trigrams in the text are (blank substituted by underline `_` for better demonstration):
# 1. `it_`
# 2. `t_w`
# 3. `_wa`
# 4. `was`
# 5. `as_`
#
# In the variable `q11_1` place the most common trigram in the text. In the variable `q11_2` place the number of times the most common trigram shows in the text.

# %%
# Code for question 11
q11_1 = ...
q11_2 = ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# # AI Disclosure
#
# Use the **Artificial Intelligence Disclosure (AID) Framework** to explain your use of AI on this assignment. Other headings you can use include:
#
# - *Debugging:* Using AI to help you fix your code so that it works. You should state how you used it for this purpose.
#
# Here are some examples:
#
# *Artificial Intelligence Tools:* ChatGPT v5 via chatgpt.com. *Conceptualization:* I gave chatgpt.com the election data set and asked it for ideas on interesting statistics I could get from the data. *Methodology:* I asked it for help on how to write the code to get the statistic I chose, but I wrote the code myself. *Writing — Review & Editing:* I wrote out my explanation for what the statistic meant, then gave that text and the rubric to chatgpt and asked it to give me feedback on how to update the explanation to conform to the rubric.
#
# *Artificial Intelligence Tools:* ChatGPT v4o via DukeGPT. *Information Collection:* DukeGPT was used to find the function needed to get the index value of the maximum value of a Series and the syntax needed to filter rows in a pandas dataframe using multiple columns. *Debugging:* DukeGPT was used to help me find a bug in my code for Q1 where I copied in the code and error, stated what the code should do, and asked for help.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Submitting
#
# You should make sure any code that you write to answer the questions is included in this notebook. You are **required** to go to the Kernel option and choose **"Restart & Run All"** before submission. Double check that your entire notebook runs correctly and generates the expected output. Finally, make sure to save your work (timestamp at the top tells you the last checkpoint and whether there are unsaved changes). When you finish, submit your assignment at Gradescope. **Submissions not prepared correctly as above will lose points.**
