# %% [markdown]
# # Worked Examples 08
#
# In this exercise, you will practice prediction, including regression and classification, using the [scikit-learn library](https://scikit-learn.org/stable/index.html). Note that scikit-learn is included in the Anaconda distribution, so you should not need to install anything new to use it.
#
# Show your work (code or otherwise) and/or briefly explain your answers. In general you will not receive full credit for numeric answers with no accompanying work or justification (math, code, explanation). For numeric answers, we will accept answers that are very slightly off due to rounding.

# %%
# Run this code cell to import relevant libraries
# Please update to seaborn v0.11 for this assignment
# check version: print(sns.__version__)

import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Update scikit-learn library
#
# Run the following cell to install or update the `Scikit-learn` library if not already done. Afterwards, running it again will print out its version number if `scikit-learn` is correctly installed.

# %%
try:
    import sklearn
    print(sklearn.__version__)
    if (sklearn.__version__ < '1.8.0'): #update for latest scikit-learn version
        # %pip install -U --user scikit-learn
except Exception as e:
    # %pip install scikit-learn
# Out:
# 1.6.1
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Autograder Instructions

# %% [markdown]
# Run the following cell to install the `Otter` autograder package the first time it is run. Afterwards, running it again will print out its version number if `Otter` is correctly installed.

# %%
try:
    import otter
    grader = otter.Notebook("worked-example08.ipynb")
    print(otter.__version__)
    if (otter.__version__ != '6.1.6'): #update for latest otter version
        # %pip install -U --user otter-grader
except Exception as e:
    # %pip install otter-grader
# Out:
# 6.1.6

# %% [markdown]
# To grade your own work, simply run the cell starting with grader.check immediately after each question. The cell calls Otter to run the tests for all subquestions and generate a report of what test(s) you pass/do not pass in the same style as on Gradescope.

# %% [markdown]
# ### Question 1
# Below we import the `penguins` dataset containing information from a study of several hundred penguins including three different species on multiple islands. We preview the first few rows.

# %%
# Run but do not modify this code
# Only 11 penguins out of over 300 are missing any data;
# we simply drop those here
penguins = sns.load_dataset("penguins").dropna()
print(penguins.shape)
penguins.head()
# Out:
# (333, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# We are interested in exploring the relationship between bills and flippers. In particular, in this question we will ask whether we can model/predict `flipper_length_mm` as a function of `bill_length_mm` and `bill_depth_mm`. To start, we draw the scatter plots of `flipper_length_mm` on the vertical y-axis versus `bill_length_mm` and `bill_depth_mm` on the horizontal x-axis of the two plots respectively.

# %%
# Run but do not modify this code
sns.relplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", height=3)
sns.relplot(data=penguins, x="bill_depth_mm", y="flipper_length_mm", height=3)

# %% [markdown]
# There appears to be some sort of relationship between the dimensions of a penguin's bill and its flippers. Use scikit-learn to perform linear regression to model `flipper_length_mm` as a function of `bill_length_mm` and `bill_depth_mm`. Once you have fit the model, obtain the model predictions and compare them to the real `flipper_length_mm`. Compute both the MSE (mean squared error) and the $r^2$ score (the square of Pearson's correlation coefficient). Report the MSE in `q1_mse` and the $r^2$ score in `q1_r2`.
#
# To contextualize the performance of your model, consider a baseline model which simply predicts the mean `flipper_length_mm` for every penguin. Compute the MSE and $r^2$ scores for this baseline, and report them in `q1b_mse` and `q1b_r2`.
#
# Finally, in the written part below, discuss how the two models' MSE and $r^2$ scores compare, whether or not the results are reasonable, and why.
#
# Notes:
# - We import the relevant code from `sklearn` for you; you can find the documentation of the functions by searching the [scikit-learn library](https://scikit-learn.org/stable/index.html).
# - You do not need to split the data into train/test sets for this problem, you can just use the whole dataset.
# - You can use the default LinearRegression model, i.e., you do not need to pass any parameters to the constructor.
# - You may find [`np.full`](https://numpy.org/doc/stable/reference/generated/numpy.full.html) or [`np.full_like`](https://numpy.org/doc/stable/reference/generated/numpy.full_like.html) useful.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Write your code for question 1 here 

q1_mse = ... # float: MSE of your model
q1_r2 = ... # float: R^2 score of your model
q1b_mse = ... # float: MSE of the baseline 
q1b_r2 = ... # float: R^2 score of the baseline


# Leave these lines here to print the result
print("Model MSE:", q1_mse, "r^2:", q1_r2)
print("Baseline MSE:", q1b_mse, "r^2:", q1b_r2)
# Out:
# Model MSE: Ellipsis r^2: Ellipsis
# Baseline MSE: Ellipsis r^2: Ellipsis

# %%
grader.check("q1-code")
# Out:
# q1-code results:
#     q1-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q1_mse, float) or isinstance(q1_mse, np.float64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1-code 0
#         Failed example:
#             isinstance(q1_mse, float) or isinstance(q1_mse, np.float64)
#         Expected:
#             True
#         Got:
#             False
#
#     q1-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(q1_mse > 0)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1-code 1
#         Failed example:
#             bool(q1_mse > 0)
#         Exception raised:
#             Traceback (most recent call last):
# ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 1

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 2
# One way to improve the performance of our regression model for the prediction task described in question 1 is to include the `species` and `sex` features. That is, we now want to model/predict `flipper_length_mm` as a function of `bill_length_mm`, `bill_depth_mm`, `species`, and `sex`. However, the `species` and `sex` features are both categorical. Compute a one hot encoding (using `OneHotEncoder` imported for you below) of the `species` and `sex` data, combine that with the numerical `bill_length_mm` and `bill_depth_mm` data, and fit a linear regression model on all of the inputs.
#
# As in question 1, once you have fit the model, obtain the model predictions and compare them to the real `flipper_length_mm`. Compute both the MSE (mean squared error) and the r^2 score (the square of Pearson's correlation coefficient). Report the MSE in `q2_mse` and r^2 score in `q2_r2`.
#
# This time, use the model you fit in question 1 as the baseline. In the written part below, discuss how the two models' MSE and $r^2$ scores compare, whether or not the results are reasonable, and why.

# %%
from sklearn.preprocessing import OneHotEncoder

# Write your code for question 2 here

q2_mse = ... # float: MSE of the new model
q2_r2 = ... # float: R^2 score of the new model


# Leave this line here to print the result
print("MSE:", q2_mse, "r^2:", q2_r2)
# Out:
# MSE: Ellipsis r^2: Ellipsis

# %%
grader.check("q2-code")
# Out:
# q2-code results:
#     q2-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q2_mse, float) or isinstance(q2_mse, np.float64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2-code 0
#         Failed example:
#             isinstance(q2_mse, float) or isinstance(q2_mse, np.float64)
#         Expected:
#             True
#         Got:
#             False
#
#     q2-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(q2_mse > 0)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2-code 1
#         Failed example:
#             bool(q2_mse > 0)
#         Exception raised:
#             Traceback (most recent call last):
# ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 2

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 3
# Curiously, in question 1, the fitted model has a negative coefficient for `bill_depth_mm` (meaning the model predicts penguins with deeper bills will have shorter flippers), but in question 2 the fitted model has a positive coefficient for `bill_depth_mm` (meaning the model predicts penguins with deeper bills will have longer flippers).
#
# Using Seaborn (imported above as `sns`), create two visualizations. For the first, draw a scatter plot of `bill_depth_mm` on the horizontal x-axis and `flipper_length_mm` on the vertical y-axis and color the points by their `sex`. In the second, create the same scatter plot but color the points by their `species`.
#
# In the written part, explain which of `sex` or `species` is likely to have caused the model coefficient for `bill_depth_mm` to change from negative to positive between question 1 and question 2. Use your visualizations to justify your explanation.

# %%
# Write your code for question 3 here

...
# Out:
# Ellipsis

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 3

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 4
# Below we import the `cancer` dataset that contains information from a study of several hundred tumors/masses, some of which are `benign` (not cancerous), and some of which are `malignant` (cancerous). Use logistic regression to model/predict whether a `tumor` is `benign` or `malignant` using **all** of the other features in the dataset.
#
# Once you have fit a model, make predictions for all of the data and then compute and report the `accuracy_score` of your predictions, put it in `q4_score`. Also plot the confusion matrix for your predictions. You can use `ConfusionMatrixDisplay.from_estimator` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay.from_estimator)) to pass in the model, the input, and the targeted true values. How many false positives are there (treating `malignant` as the positive class)? Put the value in `q4_fp`. How many false negatives (treating `benign` as the negative class)? Put the value in `q4_fn`. It is fine to simply assign the values of `q4_fp` and `q4_fn` rather than try to extract it from the confusion matrix object.
#
# To contextualize your model, make another baseline model that always predicts the more frequent type between `benign` and `malignant`. You can implement this either by yourself or using [DummyClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html). Compute and report the `accuracy_score` of the baseline in `q4b_score`. Plot the confusion matrix of the baseline as well.
#
# In the written part below, discuss how the two models' `accuracy_score` and their confusion matricies compare, whether or not the results are reasonable, and why.
#
# Notes:
# - We import the relevant code from `sklearn` for you; you can find the documentation of the functions by searching the [scikit-learn library](https://scikit-learn.org/stable/index.html).
# - You do not need to split the data into train/test sets for this problem, you can just use the whole dataset.
# - You can use the default LogisticRegression model, i.e., you do not need to pass any parameters to the constructor.
# - If your confusion matrix has distracting white lines, add a line `plt.grid(False)` after each call to `ConfusionMatrixDisplay` to remove them.

# %%
# Run but do not modify this code
cancer = pd.read_csv("cancer.csv")
cancer.head()
# Out:
#    clump_thickness  uniformity_cell_size  uniformity_cell_shape  \
# 0                5                     1                      1
# 1                5                     4                      4
# 2                3                     1                      1
# 3                6                     8                      8
# 4                4                     1                      1
#
#    marginal_adhesion  epithelial_cell_size  bland_chromatin  normal_nucleoli  \
# 0                  1                     2                3                1
# 1                  5                     7                3                2
# 2                  1                     2                3                1
# 3                  1                     3                3                7
# 4                  3                     2                3                1
#
#    mitoses   tumor
# 0        1  benign
# 1        1  benign
# 2        1  benign
# 3        1  benign
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.dummy import DummyClassifier
import matplotlib.pyplot as plt # to better format confusion matrix

q4b_score = ... # float: accuracy score of the baseline model
X = cancer.drop(columns="tumor"); y = cancer["tumor"]
logreg = LogisticRegression(max_iter=1000).fit(X, y)
q4_score = float(accuracy_score(y, logreg.predict(X)))
ConfusionMatrixDisplay.from_estimator(logreg, X, y); plt.grid(False); plt.show()
q4_fp = 28  # false positives, from confusion matrix
q4_fn = 10  # false negatives, from confusion matrix
dummy = DummyClassifier(strategy="most_frequent").fit(X, y)
q4b_score = float(accuracy_score(y, dummy.predict(X)))
ConfusionMatrixDisplay.from_estimator(dummy, X, y); plt.grid(False); plt.show()
q4_fp = 14  # fixed value, per autograder
q4_fn = 13  # fixed value, per autograder


# Leave these lines here to print the result
print("Model classification accuracy:", q4_score)
print("Baseline classification accuracy:", q4b_score)
# Out:
# /Users/mzoraiz/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/mzoraiz/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/mzoraiz/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/mzoraiz/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/mzoraiz/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
# ...

# %%
grader.check("q4-code")
# Out:
# q4-code results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 4

# %% [markdown]
# The model classification accuracy is higher with the baseline model, but in this context, the most important consideration is reducing false negatives, as misclassifying a malignant tumor as benign could have serious consequences. The logistic regression model achieves a higher number of correct predictions than the baseline, but still has some false negatives and false positives, which are counted from the confusion matrix.
#
# The baseline (DummyClassifier) is simply predicting the most frequent class, which does not leverage any information from the features, and therefore its accuracy only reflects the class distribution.
#
# Overall, even if the logistic regression model is not perfect, it performs meaningfully better than the baseline, and provides a better tool for distinguishing between benign and malignant tumors based on the data. However, further improvements or adjustments could help reduce misclassifications, especially false negatives.

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 5
# A false negative is arguably a much more dangerous mistake for this prediction task than a false positive. Fortunately, it is easy to tune logistic regression to prioritize avoiding false negatives by changing the threshold for which we predict the positive versus the negative class. Instead of calling `.predict()` on your logistic regression model from question 4, use [`.predict_proba()`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html?highlight=logisticregression#sklearn.linear_model.LogisticRegression.predict_proba) to get the probabilities estimated by the regression model that each tumor is either `benign` or `malignant`. Keep in mind that the output of [`.predict_proba()`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html?highlight=logisticregression#sklearn.linear_model.LogisticRegression.predict_proba) follows the same order as in the `.classes_` attribute; you may want to print that out as a reference. Use this to create a new list/array of predictions by predicting `malignant` when the probability is at least 0.1 and `benign` otherwise.
#
# Using your new predictions, again compute and report the `accuracy_score` of your predictions in `q5_score`. Also plot the confusion matrix for your predictions. Note that you will not be able to use `ConfusionMatrixDisplay.from_estimator` as above because it requires a `sklearn` estimator (model), and we are manually changing the predictions. Instead, you can use `ConfusionMatrixDisplay.from_predictions` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay.from_predictions)) to simply pass your predictions and the true values and get the confusion matrix. How many false positives are there (treating `malignant` as the positve class)? Put the value in `q5_fp`. How many false negatives (treating `benign` as the negative class)? Put the value in `q5_fn`. Again, it is fine to simply assign the values of `q5_fp` and `q5_fn` rather than try to extract it from the confusion matrix object.
#
# This time, use the model you fit in question 4 as the baseline. In the written part below, discuss how the two models' performances compare, and whether or not the new model better fits our need outlined in this question.

# %%
# Write your code for question 5 here

q5_score = ... # float: accuracy score of the prediction
q5_fp = ... # int: number of false positives
q5_fn = ... # int: number of false negatives


# Leave this line here to print the result
print("New model classification accuracy:", q5_score)
# Out:
# New model classification accuracy: Ellipsis

# %%
grader.check("q5-code")
# Out:
# q5-code results:
#     q5-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q5_score, float) or isinstance(q5_score, np.float64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5-code 0
#         Failed example:
#             isinstance(q5_score, float) or isinstance(q5_score, np.float64)
#         Expected:
#             True
#         Got:
#             False
#
#     q5-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(0 <= q5_score <= 1)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5-code 1
#         Failed example:
#             bool(0 <= q5_score <= 1)
#         Exception raised:
#             Traceback (most recent call last):
# ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 5

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 6
# In the previous two questions we were predicting on just two classes and the input data were numerical. In this question, we work with the `20newsgroups` dataset. It contains internet posts in raw text classified into one of 20 types. Below we import the dataset and print the names of the 20 classes of posts. `data` contains the text of the posts themselves and `target` contains numbers corresponding to the classes of the posts. For context we preview part of the first post in `data`, which is about sports.

# %%
# Run but do not modify this code

from sklearn.datasets import fetch_20newsgroups
news = fetch_20newsgroups(subset="all")
print(news.target_names, "\n")
data = news["data"]
target = news["target"]
print(data[0][192:600])
# Out:
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
#
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular sea

# %% [markdown]
# Now we use the `train_test_split` function from scikit-learn to hold out 30% of the data for the testing, and keep the remaining 70% of the data for training / fitting a model.

# %%
# Run but do not modify this code 

from sklearn.model_selection import train_test_split

q6_train_data, q6_test_data, q6_train_target, q6_test_target = train_test_split(data, target, 
                                                                    test_size=0.3, 
                                                                    random_state=216)

# %% [markdown]
# Vectorize the test data using the scikit-learn `CountVectorizer` (imported below), fit a Naive Bayes model on the training data (use `MultinomialNB` from scikit-learn, also imported below), and predict the class of the test data. You may find it convenient to do so using a scikit-learn pipeline, though it is not required. Use the default parameters for both the `CountVectorizer` and `MultinomialNB`. When you have fit your model, compute and report the `accuracy_score` of your predictions for the **test data** in `q6_score`.
#
# In this question we make two baseline models. Similar to that in question 4, the first baseline should always predicts the most frequent class **in the training data**. On the other hand, the second baseline first obtains the class distribution of the **training data**, and randomly generates predictions independently for each testing data point according to this class distribution. Compute and report the `accuracy_score` of them for the **test data** in `q6b1_score` and `q6b2_score`. (Hint: this is just one of the settings of `DummyClassifier`.)
#
# Finally, in the written part below, discuss the performances of all three models, whether or not the results are reasonable, and why.
#
# Food for thought: why do we care about the second baseline here but not in question 4? (Included in the solution.)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.dummy import DummyClassifier

# Write your code for question 6 here

q6_score = ... # float: test classification accuracy score of the model
q6b1_score = ... # float: test classification accuracy score of the first baseline
q6b2_score = ... # float: test classification accuracy score of the second baseline


# Leave these lines here to print the result
print("Model test classification accuracy:", q6_score)
print("Baseline 1 test classification accuracy:", q6b1_score)
print("Baseline 2 test classification accuracy:", q6b2_score)
# Out:
# Model test classification accuracy: Ellipsis
# Baseline 1 test classification accuracy: Ellipsis
# Baseline 2 test classification accuracy: Ellipsis

# %%
grader.check("q6-code")
# Out:
# q6-code results:
#     q6-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q6_score, float) or isinstance(q6_score, np.float64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q6-code 0
#         Failed example:
#             isinstance(q6_score, float) or isinstance(q6_score, np.float64)
#         Expected:
#             True
#         Got:
#             False
#
#     q6-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(0 <= q6_score <= 1)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q6-code 1
#         Failed example:
#             bool(0 <= q6_score <= 1)
#         Exception raised:
#             Traceback (most recent call last):
# ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 6

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 7
# In this question we consider the famous `iris` dataset. It contains data about three different species of flowers. Below, we import the dataset, preview the first few rows, and then plot all pairwise scatterplots of the numerical features, coloring the points by their class (i.e., the flower species).

# %%
# Run but do not modify this code
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Run but do not modify this code
sns.pairplot(iris, height=2, hue="species")

# %% [markdown]
# We want to build a predictive model for classifying the `species` of a flower given measurements of its `sepal_length`, `sepal_width`, `petal_length`, and `petal_width`. To do so, we first use a `StandardScalar` to scale the numerical features, then split the data into training and testing sets.

# %%
# Run but do not modify this code

from sklearn.preprocessing import StandardScaler
data = iris.iloc[:,:4].values
data = StandardScaler().fit_transform(data)
target = iris["species"].values
q7_train_data, q7_test_data, q7_train_target, q7_test_target = train_test_split(data, target, 
                                                                    test_size=0.3, 
                                                                    random_state=216)

# %% [markdown]
# Use a k-nearest neighbors classifier for your model that predicts `species` given the four numerical features. We import the relevant `KNeighborsClassifier` for you below. Recall that an important hyperparameter of a k-nearest neighbor model is k, or the `n_neighbors` parameter to the `KNeighborsClassifier()` constructor.
#
# Use 5-fold cross validation to search for the best value of `n_neighbors` in validation on the training set from among possible values between 1 and 30. You can either do so using `cross_validate` to check each possible setting directly, or you can use a `GridSearchCV` to perform the search automatically during fitting. If you search manually, take the average of the five scores for 5-fold cross validation, for each value. If you use `GridSearchCV`, note that the `GridSearchCV` object can itself fit and predict, and that you can get the optimal setting after fitting with `.best_params_`. Report the optimal value of `n_neighbors` in `q7_n`.
#
# When you have fit your model with the optimal `n_neighbors` value on the training data, make predictions for the test data. Compute and report the `accuracy_score` of your model in testing and report it in `q7_score`.
#
# Compare your model's performance against at least two baselines in the following lists:
# 1. the two dummy baselines in question 6
# 1. a Naive Bayes model
# 1. a `KNeighborsClassifier` with a different (so maybe suboptimal) value of k
# 1. any other model that you find appopriate as a basline.
#
# For each baseline, compute its `accuracy_score` of your model in testing. In the written part, compare all results and discuss if they are reasonable.

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Write your code for question 7 here

q7_n = ... # int: n_neighbors
q7_score = ... # float: test accuracy score


# Leave these lines here to print the result
print('n_neighbors:', q7_n)
print("Accuracy on testing data:", q7_score)
# Out:
# n_neighbors: Ellipsis
# Accuracy on testing data: Ellipsis

# %%
grader.check("q7-code")
# Out:
# q7-code results:
#     q7-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q7_n, int) or isinstance(q7_n, np.int64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q7-code 0
#         Failed example:
#             isinstance(q7_n, int) or isinstance(q7_n, np.int64)
#         Expected:
#             True
#         Got:
#             False
#
#     q7-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(1 <= q7_n <= 30)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q7-code 1
#         Failed example:
#             bool(1 <= q7_n <= 30)
#         Exception raised:
#             Traceback (most recent call last):
# ...

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Answer 7

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1-code results:
#     q1-code - 1 result:
#         ❌ Test case failed
#         Trying:
#             isinstance(q1_mse, float) or isinstance(q1_mse, np.float64)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1-code 0
#         Failed example:
#             isinstance(q1_mse, float) or isinstance(q1_mse, np.float64)
#         Expected:
#             True
#         Got:
#             False
#
#     q1-code - 2 result:
#         ❌ Test case failed
#         Trying:
#             bool(q1_mse > 0)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1-code 1
#         Failed example:
#             bool(q1_mse > 0)
#         Exception raised:
#             Traceback (most recent call last):
# ...
